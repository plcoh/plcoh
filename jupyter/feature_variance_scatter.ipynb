# %%
# %cd '/home/threadripper/PycharmProjects/plcoh'
# Out:
# /home/threadripper/PycharmProjects/plcoh

# %%
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from scipy.stats import spearmanr
from services.coherence_service import CoherenceService

# %%
mpl.rcParams['figure.dpi'] = 200

# %%
coherence_service = CoherenceService()
coherence_service.load_from_cache()

# %%
coherence_service.data
# Out:
#         length  log_length  c_length  num_edits  log_num_edits  c_num_edits  \
# 657000      80    4.382027         1         16       2.772589            1
# 657001      28    3.332205         0         22       3.091042            1
# 657004      27    3.295837         0          4       1.386294            0
# 657005      23    3.135494         0          5       1.609438            1
# 657006      43    3.761200         1          4       1.386294            0
# ...        ...         ...       ...        ...            ...          ...
# 956992      15    2.708050         0          2       0.693147            0
# 956993      44    3.784190         1         15       2.708050            1
# 956994      17    2.833213         0          4       1.386294            0
# 956997      22    3.091042         0          9       2.197225            1
# 956999      24    3.178054         0         18       2.890372            1
#
#         popularity  c_popularity  c_collaborative  danceability    energy  \
# 657000    8.073578             2                0     -0.204423  0.004966
# 657001    7.157755             1                0      0.048512  0.036950
# 657004    8.244777             2                0      0.239329  0.162633
# 657005    6.363797             1                0      0.073375 -0.128113
# 657006    8.870327             2                0     -0.157039  0.355360
# ...            ...           ...              ...           ...       ...
# 956992    8.081339             2                0     -0.058965  0.043485
# 956993    8.009465             2                0     -0.084521 -0.012339
# 956994    5.778014             0                0     -0.074460 -0.054699
# 956997    8.381551             2                0      0.237690  0.306554
# 956999    8.830691             2                0      0.090113  0.038466
#
#         loudness  speechiness  acousticness  instrumentalness  liveness  \
# 657000  0.050241    -0.070003      0.215957         -0.031432 -0.110339
# 657001  0.096431    -0.269302      0.109809         -0.064993 -0.153084
# 657004 -0.170984     0.178848      0.190761         -0.047002 -0.037788
# 657005 -0.058370    -0.188093     -0.111972          0.033246  0.041553
# 657006  0.362817     0.112197      0.261058          0.043628  0.104775
# ...          ...          ...           ...               ...       ...
# 956992 -0.147843    -0.023632     -0.219811               NaN -0.119055
# 956993 -0.198269     0.090764     -0.089335               NaN  0.072942
# 956994 -0.009119    -0.169055      0.218348               NaN  0.112013
# 956997  0.025996    -0.059190      0.271303         -0.097251 -0.157598
# 956999 -0.115751     0.327162     -0.023470               NaN  0.149962
#
#          valence     tempo  tonality   artists
# 657000  0.070400 -0.131460  0.155342  0.029116
# 657001 -0.091908 -0.025809  0.027100  0.067336
# 657004  0.013248  0.071527 -0.131989  0.062189
# 657005  0.150926 -0.378288 -0.228606  0.204304
# 657006 -0.125808  0.012618  0.057037  0.195153
# ...          ...       ...       ...       ...
# 956992 -0.095128  0.040446 -0.243872 -0.017093
# 956993  0.104070  0.199087  0.168419  0.017132
# 956994 -0.386230  0.311817 -0.034969  0.419643
# 956997  0.139749 -0.267555 -0.065046 -0.001489
# 956999 -0.253698  0.298365  0.061795  0.000273
#
# [650485 rows x 20 columns]

# %%
def plot(data: pd.DataFrame, independent_variable, dependent_variable, size=10000):
    f = plt.figure(figsize=(9, 9))
    samples = data[~data[dependent_variable].isna()].sample(size)
    x = samples[independent_variable]
    y = samples[dependent_variable]
    
    ax = sns.jointplot(x=x, y=y, kind="hex")
    print(spearmanr(x, y))
    return ax

# %%
plot(coherence_service.data, 'popularity', 'energy', 100000)
# Out:
# SignificanceResult(statistic=np.float64(-0.08587399038513725), pvalue=np.float64(5.566145181137853e-163))
